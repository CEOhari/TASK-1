# %% [markdown]
# ### THEORY CONCEPTS: DATA ANALYSIS

# %% [markdown]
# ### What is Data Analysis?
# * Data analysis is the process of collecting, cleaning, and studying data to find useful information and make decisions.

# %% [markdown]
# ### Pandas Library

# %% [markdown]
# ###  What is Pandas?
# * Pandas is a Python library used for data analysis and data manipulation.

# %% [markdown]
# ### Reading Data from CSV Files

# %% [markdown]
# ### What is a CSV File?
#
# * CSV = Comma Separated Values
#
# * Stores data in rows and columns
#
# * Marks sheet saved as marks.csv
#
# ### Example
# * data = pd.read_csv("marks.csv")
# * read_csv() → opens the file

# %% [markdown]
# ### Data is stored in a DataFrame (table format)

# %% [markdown]
# ####  Exploring Data (Understanding the Dataset)
#
# ### Before analysis, we look at the data.
#
# * View First Few Rows
# * data.head()
#
# Shows first 5 rows
#
# * View Last Few Rows
# * data.tail()
#
# ### Basic Information About Data
# * data.info()
#
# * Column names
#
# * Data types
#
# * Missing values
#
# * Statistical Summary
# * data.describe()
# * Average (mean)
# * Minimum
# * Maximum

# %% [markdown]
# #### Data Cleaning (Fixing Errors)
#
# ### What is Data Cleaning?
#
# Data cleaning means fixing or removing wrong, missing, or duplicate data.
#
# Why It’s Important?
#
# Wrong data = wrong results
#
# Clean data = correct analysis
#
# * Handling Missing Values
# * Check missing values
# * data.isnull()
#
# * Remove missing values
# * data.dropna()
#
# * Fill missing values
# * data.fillna(0)

# %% [markdown]
# ### Simple Statistics (Basic Calculations)
#
# #### Statistics help us summarize data.
#
# * Average (Mean)
# * data["Marks"].mean()
#
#
# * Finds average marks
# * Maximum Value
# * data["Marks"].max()
#
#
# * Highest marks
# * Minimum Value
# * data["Marks"].min()
