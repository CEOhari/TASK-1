# %% [markdown]
# ### What is Programming?

# %% [markdown]
# Programming means telling the computer what to do step by step using instructions written in a language like Python.

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# ### Why Python?
#
# Easy to read (English-like)
#
# Beginner-friendly
#
# Used in Data Analysis, AI, Web, Automation

# %% [markdown]
# ### Variables
#
# Variables are containers that store data.

# %%
name = "Alex"
age = 21
is_student = True

# %% [markdown]
# ### Basic Math Operations

# %%
a = 10
b = 5

print(a + b)   # Addition
print(a - b)   # Subtraction
print(a * b)   # Multiplication
print(a / b)   # Division
# Out:
# 15
# 5
# 50
# 2.0

# %% [markdown]
# ### Strings (Text Data)

# %%
first_name = "Alex"
hobby = "Coding"

print(first_name + " loves " + hobby)
# Out:
# Alex loves Coding

# %% [markdown]
# ### Lists

# %%
foods = ["Pizza", "Burger", "Biryani"]

print(foods[0])  # Pizza
print(foods[1])  # Burger
# Out:
# Pizza
# Burger

# %% [markdown]
# ### Day 1: Setup & First Program

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ### Day 2: Variables & User Input

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")
city = input("Enter your city: ")

print(name, age, city)
# Out:
# Enter your name:  hari
# Enter your age:  24
# Enter your city:  chennai
# hari 24 chennai

# %% [markdown]
# ### Day 3: Welcome Message (f-strings)

# %%
print(f"Hello {name}, you are {age} years old and live in {city}.")
# Out:
# Hello hari, you are 24 years old and live in chennai.

# %% [markdown]
# ### Day 4: Enhance Program

# %% [markdown]
# ### FINAL PROJECT — Personal Introduction Program

# %%
# Personal Introduction Program
# Week 1 Python Project

name = input("What is your name? ")
age = input("How old are you? ")
hobby = input("What is your favorite hobby? ")
city = input("Which city are you from? ")

print("\n🎉 Welcome", name + "! 🎉")
print(f"You are {age} years old.")
print(f"You live in {city}.")
print(f"And you love {hobby}.")
print("\nNice to meet you! 😊")
# Out:
# What is your name?  hari
# How old are you?  24
# What is your favorite hobby?  carrom board
# Which city are you from?  chennai
# 🎉 Welcome hari! 🎉
# You are 24 years old.
# You live in chennai.
# And you love carrom board.
#
# Nice to meet you! 😊
